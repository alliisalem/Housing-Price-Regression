# %% [markdown]
# # Phase 1: Business Understanding
#
# **CRISP-DM Phase Description:**
# This phase focuses on understanding the project objectives and requirements from a business perspective, then converting this knowledge into a data mining problem definition and a preliminary plan designed to achieve the objectives.
#
# ---

# %% [markdown]
# ### Task 1: Determine Business Objectives
#
# The first objective of the data analyst is to thoroughly understand, from a business perspective, what the customer really wants to accomplish. This involves:
#
# - **Background:** Identify the organisational context and the business area the project relates to.
# - **Business Objectives:** Clearly state the primary question or problem the business wants to solve.
# - **Business Success Criteria:** Define the measurable criteria that determine whether the project's outcome is considered a success from the business's point of view (e.g., "reduce customer churn by 15%", "improve prediction accuracy to 90%").
#
# **Instructions:** In the cells below, define your business objectives, background context, and success criteria as Python variables (strings or dictionaries). This ensures your business logic is documented directly in the notebook's code state.

# %%
business_objectives = {
    "background": (
        "This project is in the real estate analytics. A property investor or housing market "
        "analyst wants to use historical housing data to estimate sale prices, understand how home "
        "features affect value, and identify neighbourhoods where properties may be selling lower than "
        "their expected market value."
    ),
    "primary_objective": (
        "Build a data solution to predict house sale prices and identify"
        "undervalued neighbourhoods for investment opportunities."
    ),
    "success_criteria": [
        "Make a reliable price prediction model that estimates saleprice with low error.",
        "Identify neighbourhoods where actual sale prices are consistently lower than predicted prices.",
        "Measure the effect of important property features such as bathroom count, living area, and basement area on sale price.",
        "Produce business-friendly findings that can support property investment and pricing decisions."
    ]
}

# %%
# Display the defined objectives in a readable format
for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"   - {item}")
    else:
        print(f"   {value}")
    print()
# Out:
# >> BACKGROUND:
#    This project is in the real estate analytics. A property investor or housing market analyst wants to use historical housing data to estimate sale prices, understand how home features affect value, and identify neighbourhoods where properties may be selling lower than their expected market value.
#
# >> PRIMARY OBJECTIVE:
#    Build a data solution to predict house sale prices and identifyundervalued neighbourhoods for investment opportunities.
#
# >> SUCCESS CRITERIA:
#    - Make a reliable price prediction model that estimates saleprice with low error.
#    - Identify neighbourhoods where actual sale prices are consistently lower than predicted prices.
#    - Measure the effect of important property features such as bathroom count, living area, and basement area on sale price.
#    - Produce business-friendly findings that can support property investment and pricing decisions.

# %% [markdown]
# ---
# ### Task 2: Assess Situation
#
# This task involves a more detailed fact-finding about all of the resources, constraints, assumptions, and other factors that should be considered in determining the data analysis goal and project plan. Key areas to assess:
#
# - **Resources Inventory:** Personnel, data sources, computing resources, and software available.
# - **Requirements, Assumptions, and Constraints:** Project schedule, legal/ethical considerations, data access limitations, and budget.
# - **Risks and Contingencies:** Identify potential risks (e.g., data unavailability, quality issues, privacy concerns) and how to mitigate them.
# - **Terminology Glossary:** Define key domain-specific terms relevant to the project.
# - **Costs and Benefits:** A cost-benefit analysis of the project.
#
# **Instructions:** Document your situation assessment as a structured dictionary or set of variables.

# %%
situation_assessment = {
    "resources": {
        "personnel": [
            "Student data analyst",
            "Course instructor / project supervisor",
            "Potential domain knowledge from real estate market reports or dataset documentation"
        ],
        "data_sources": [
            "Ames Housing dataset (Kaggle) or California Housing dataset",
            "Dataset documentation / data dictionary",
            "Notebook file for project development"
        ],
        "computing": "Local machine using Anaconda Prompt / Jupyter Notebook",
        "software": [
            "Python 3.x",
            "Jupyter Notebook",
            "pandas",
            "numpy",
            "matplotlib",
            "scikit-learn"
        ]
    },
    "requirements": [
        "Use a structured CRISP-DM workflow.",
        "Perform the work in Python through Anaconda/Jupyter Notebook.",
        "Create a regression-based solution because the target is house sale price.",
        "Keep outputs clear enough for business interpretation."
    ],
    "assumptions": [
        "The dataset is sufficiently representative of the housing market covered by the data.",
        "Important pricing drivers such as size, quality, age, and neighbourhood are available in the dataset.",
        "Historical sale patterns can help predict future or unseen house prices.",
        "Neighbourhood-level residual patterns can be used as a proxy for undervaluation opportunities."
    ],
    "constraints": [
        "Project is limited to the features available in the selected dataset.",
        "External economic factors such as interest rates and inflation may not be included.",
        "The project is conducted on a local machine with limited computational power.",
        "Time is limited to the course schedule and project phases."
    ],
    "risks_and_contingencies": [
        {
            "risk": "Missing values or inconsistent data quality",
            "impact": "Can reduce model performance and bias results",
            "contingency": "Use data cleaning, imputation, and feature screening during data preparation"
        },
        {
            "risk": "Overfitting to the training data",
            "impact": "Model performs well in training but poorly on unseen data",
            "contingency": "Use train-test split, cross-validation, and compare simpler vs stronger models"
        },
        {
            "risk": "Chosen dataset may not fully answer the business question",
            "impact": "Some business insights may be limited",
            "contingency": "State scope clearly and focus conclusions on available variables only"
        },
        {
            "risk": "Interpretability may be weak for complex models",
            "impact": "Business users may not trust the output",
            "contingency": "Include an interpretable baseline model and explain important features"
        }
    ],
    "glossary": {
        "SalePrice": "The final sale price of a property; the target variable for prediction.",
        "Regression": "A predictive modelling technique used to estimate a continuous numeric value.",
        "Neighbourhood": "The area or district in which a property is located.",
        "Residual": "The difference between actual sale price and predicted sale price.",
        "Undervalued Property": "A property or neighbourhood where actual prices are lower than expected based on model predictions."
    },
    "costs_and_benefits": {
        "costs": [
            "Time required for cleaning data, modelling, and evaluation",
            "Local computing resources and student effort",
            "Possible limitations from using only one public dataset"
        ],
        "benefits": [
            "Supports better investment decision-making",
            "Helps estimate property values more consistently",
            "Reveals which features add the most value",
            "Can highlight neighbourhoods with possible investment upside"
        ]
    }
}

# %%
# Display situation assessment
import json
print(json.dumps(situation_assessment, indent=2))
# Out:
# {
#   "resources": {
#     "personnel": [
#       "Student data analyst",
#       "Course instructor / project supervisor",
#       "Potential domain knowledge from real estate market reports or dataset documentation"
#     ],
#     "data_sources": [
#       "Ames Housing dataset (Kaggle) or California Housing dataset",
#       "Dataset documentation / data dictionary",
#       "Notebook file for project development"
#     ],
#     "computing": "Local machine using Anaconda Prompt / Jupyter Notebook",
#     "software": [
#       "Python 3.x",
#       "Jupyter Notebook",
#       "pandas",
#       "numpy",
#       "matplotlib",
#       "scikit-learn"
#     ]
#   },
#   "requirements": [
#     "Use a structured CRISP-DM workflow.",
#     "Perform the work in Python through Anaconda/Jupyter Notebook.",
#     "Create a regression-based solution because the target is house sale price.",
#     "Keep outputs clear enough for business interpretation."
#   ],
#   "assumptions": [
# ...

# %%
# Optional: Add any further notes or elaboration on the situation assessment

# %% [markdown]
# ---
# ### Task 3: Determine Data Mining Goals
#
# A business goal states objectives in business terminology. A data mining goal states project objectives in technical terms. This task converts the business objectives identified in Task 1 into specific, measurable data mining goals:
#
# - **Data Mining Problem Type:** Classify the problem (e.g., classification, regression, clustering, anomaly detection, association rule mining, etc.).
# - **Data Mining Goals:** State the technical objectives clearly (e.g., "Build a classification model to predict [target variable] with an F1-score ≥ 0.85").
# - **Data Mining Success Criteria:** Define the technical metrics that will be used to evaluate the model's performance (e.g., accuracy, precision, recall, RMSE, silhouette score).
#
# **Instructions:** Map your business objectives to concrete data mining goals.

# %%
data_mining_goals = {
    "problem_type": "Regression",
    "target_variable": "SalePrice",
    "technical_goals": [
        "Prepare and clean the housing dataset for modelling.",
        "Build at least one baseline regression model and one stronger comparison model for house price prediction.",
        "Estimate SalePrice using property and neighbourhood features such as living area, basement area, quality, year built, and bathrooms.",
        "Calculate residuals (Actual - Predicted) to identify neighbourhoods that appear consistently undervalued.",
        "Measure and interpret the contribution of key features to property sale price."
    ],
    "success_metrics": [
        "R² score high enough to show useful explanatory power (target: >= 0.80 if dataset quality supports it).",
        "RMSE lower than the standard deviation of SalePrice and reasonable relative to the scale of house prices.",
        "MAE kept as low as possible for practical pricing accuracy.",
        "Neighbourhood undervaluation results are consistent across test data and interpretable."
    ]
}

# %%
# Display the mapping from business objectives to data mining goals
print("=" * 60)
print("BUSINESS TO DATA MINING GOAL MAPPING")
print("=" * 60)
print(f"\nBusiness Objective : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"\nTechnical Goals:")
for goal in data_mining_goals['technical_goals']:
    print(f"  - {goal}")
print(f"\nSuccess Metrics:")
for metric in data_mining_goals['success_metrics']:
    print(f"  - {metric}")
# Out:
# ...
# BUSINESS TO DATA MINING GOAL MAPPING
# ...
#
# Business Objective : Build a data solution to predict house sale prices and identifyundervalued neighbourhoods for investment opportunities.
# Problem Type       : Regression
# Target Variable    : SalePrice
#
# Technical Goals:
#   - Prepare and clean the housing dataset for modelling.
#   - Build at least one baseline regression model and one stronger comparison model for house price prediction.
#   - Estimate SalePrice using property and neighbourhood features such as living area, basement area, quality, year built, and bathrooms.
#   - Calculate residuals (Actual - Predicted) to identify neighbourhoods that appear consistently undervalued.
#   - Measure and interpret the contribution of key features to property sale price.
#
# Success Metrics:
#   - R² score high enough to show useful explanatory power (target: >= 0.80 if dataset quality supports it).
# ...

# %% [markdown]
# ---
# ### Task 4: Produce Project Plan
#
# Describe the intended plan for achieving the data mining goals and thereby achieving the business goals. The plan should specify:
#
# - **Tools and Techniques:** The data mining tools (libraries, frameworks) and modelling techniques you plan to use.
# - **Project Plan / Timeline:** A step-by-step plan with estimated durations for each remaining CRISP-DM phase.
# - **Dependencies:** Any dependencies between tasks or on external factors.
# - **Initial Assessment of Tools and Techniques:** A brief justification for why the chosen tools and techniques are appropriate.
#
# **Instructions:** Outline your full project plan as a structured data object below.

# %%
project_plan = {
    "tools": [
        "pandas",
        "numpy",
        "matplotlib",
        "scikit-learn",
        "Jupyter Notebook",
        "Anaconda"
    ],
    "techniques": [
        "Exploratory Data Analysis (EDA)",
        "Data cleaning and imputation",
        "Feature encoding and scaling where needed",
        "Linear Regression",
        "Random Forest Regressor",
        "Model evaluation using R², RMSE, and MAE",
        "Residual analysis by neighbourhood"
    ],
     "timeline": [
        {"phase": "Business Understanding", "duration": "Phase 1", "status": "2 Day"},
        {"phase": "Data Understanding", "duration": "Phase 2", "status": "3 Days"},
        {"phase": "Data Preparation", "duration": "Phase 3", "status": "2 Days"},
        {"phase": "Modelling", "duration": "Phase 4", "status": "5 Days"},
        {"phase": "Evaluation", "duration": "Phase 5", "status": "2 Days"},
        {"phase": "Deployment / Reporting", "duration": "Phase 6", "status": "1 Day"}
    ],
    "dependencies": [
        "Dataset must be accessible and correctly loaded into the notebook.",
        "Missing values and categorical variables must be handled before model training.",
        "Feature engineering decisions depend on the findings from data understanding.",
        "Neighbourhood investment analysis depends on having both predictions and residual calculations."
    ],
    "tool_justification": (
        "Python with pandas, numpy, matplotlib, and scikit-learn is appropriate because it provides "
        "all the main tools needed for data cleaning, visualisation, regression modelling, and "
        "evaluation in an Anaconda environment."
    )
}

# %%
# Display the project plan
print("=" * 60)
print("PROJECT PLAN")
print("=" * 60)

print("\nTools:", ", ".join(project_plan['tools']) if project_plan['tools'] else "[Not yet defined]")
print("Techniques:", ", ".join(project_plan['techniques']) if project_plan['techniques'] else "[Not yet defined]")

print("\nTimeline:")
if project_plan['timeline']:
    for phase in project_plan['timeline']:
        print(f"  [{phase.get('status', 'N/A'):^12}] {phase['phase']:<25} | {phase['duration']}")
else:
    print("  [Not yet defined]")

print("\nDependencies:")
for dep in project_plan['dependencies']:
    print(f"  - {dep}")

print(f"\nTool Justification: {project_plan['tool_justification']}")
# Out:
# ...
# PROJECT PLAN
# ...
#
# Tools: pandas, numpy, matplotlib, scikit-learn, Jupyter Notebook, Anaconda
# Techniques: Exploratory Data Analysis (EDA), Data cleaning and imputation, Feature encoding and scaling where needed, Linear Regression, Random Forest Regressor, Model evaluation using R², RMSE, and MAE, Residual analysis by neighbourhood
#
# Timeline:
#   [   2 Day    ] Business Understanding    | Phase 1
#   [   3 Days   ] Data Understanding        | Phase 2
#   [   2 Days   ] Data Preparation          | Phase 3
#   [   5 Days   ] Modelling                 | Phase 4
#   [   2 Days   ] Evaluation                | Phase 5
#   [   1 Day    ] Deployment / Reporting    | Phase 6
#
# Dependencies:
#   - Dataset must be accessible and correctly loaded into the notebook.
#   - Missing values and categorical variables must be handled before model training.
#   - Feature engineering decisions depend on the findings from data understanding.
# ...

# %%
# Optional: Summarise all Phase 1 outputs for reference in subsequent phases
print("=" * 60)
print("PHASE 1 SUMMARY: BUSINESS UNDERSTANDING")
print("=" * 60)
print(f"\nPrimary Objective  : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"Tools Planned      : {', '.join(project_plan['tools']) if project_plan['tools'] else 'TBD'}")
print(f"Techniques Planned : {', '.join(project_plan['techniques']) if project_plan['techniques'] else 'TBD'}")
# Out:
# ...
# PHASE 1 SUMMARY: BUSINESS UNDERSTANDING
# ...
#
# Primary Objective  : Build a data solution to predict house sale prices and identifyundervalued neighbourhoods for investment opportunities.
# Problem Type       : Regression
# Target Variable    : SalePrice
# Tools Planned      : pandas, numpy, matplotlib, scikit-learn, Jupyter Notebook, Anaconda
# Techniques Planned : Exploratory Data Analysis (EDA), Data cleaning and imputation, Feature encoding and scaling where needed, Linear Regression, Random Forest Regressor, Model evaluation using R², RMSE, and MAE, Residual analysis by neighbourhood
