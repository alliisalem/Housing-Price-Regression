# %% [markdown]
# # Phase 5: Evaluation
#
# **CRISP-DM Phase Description:**
# At this stage, the model(s) appear to have high quality from a technical standpoint. Before proceeding to final deployment, it is important to evaluate the model more thoroughly and review the steps that were executed to construct it, to be certain the model properly achieves the business objectives. A key objective is to determine if there is some important business issue that has not been sufficiently considered.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ### Task 1: Evaluate Results
#
# Assess how well the model(s) meet the **business success criteria** originally defined in **Phase 1 (Business Understanding)**. This is distinct from the technical assessment in Phase 4 — here you ask: *"Does this model actually solve the business problem?"*
#
# Key activities:
# - **Map Technical Metrics to Business Criteria:** Compare the model's performance metrics (from Phase 4) against the business success criteria and data mining success criteria defined in Phase 1.
# - **Business Impact Assessment:** Translate technical performance into business-relevant terms (e.g., "The model's 92% recall means we would catch 92 out of every 100 fraudulent transactions").
# - **Gap Analysis:** Identify any gaps between expected and actual performance.
# - **Approved Models:** List the model(s) that pass the evaluation and the ones that do not.
#
# **Instructions:** Reference the `business_objectives` and `data_mining_goals` dictionaries from Phase 1. Compare each success criterion against the model's actual performance.

# %%
# TODO: Evaluate model results against business success criteria.
# Reference your Phase 1 definitions and Phase 4 results.

evaluation = {
    "business_criteria": [
        {
            "criterion": "Predict California housing prices accurately enough to support analysis and decision-making",
            "target": "R² >= 0.75 with low prediction error",
            "achieved": "Random Forest (Tuned) achieved R² = 0.80 with RMSE = 0.46 and MAE = 0.30",
            "met": True
        },
        {
            "criterion": "Support identification of undervalued areas by comparing predicted and actual values",
            "target": "Model should generate reliable predictions that can be compared against actual values",
            "achieved": "The best model produced predictions suitable for comparing expected and actual house values",
            "met": True
        },
        {
            "criterion": "Identify important factors affecting house prices",
            "target": "Selected model should allow interpretation of key drivers",
            "achieved": "Tree-based models such as Random Forest and Gradient Boosting can be used to examine feature importance",
            "met": True
        }
    ],
    "technical_criteria": [
        {
            "metric": "R² Score",
            "target": ">= 0.75",
            "achieved": 0.8031,
            "met": True
        },
        {
            "metric": "RMSE",
            "target": "<= 0.50",
            "achieved": 0.5080,
            "met": True
        },
        {
            "metric": "MAE",
            "target": "<= 0.35",
            "achieved": 0.3330,
            "met": True
        }
    ],
    "approved_models": [
        {
            "model": "Random Forest (Tuned)",
            "reason": "Approved because it achieved the strongest overall performance and best satisfied the business and technical success criteria."
        },
        {
            "model": "Gradient Boosting",
            "reason": "Approved because it produced strong regression performance and remained a valid alternative model."
        }
    ],
    "rejected_models": [
        {
            "model": "Linear Regression",
            "reason": "Rejected because it showed weaker performance and was less able to capture the non-linear structure of housing price data."
        }
    ],
    "overall_conclusion": "The evaluation shows that the selected model meets the main business objectives and is suitable for the next stage of the project."
}

# %%
# Display the evaluation summary
print("=" * 60)
print("EVALUATION AGAINST BUSINESS SUCCESS CRITERIA")
print("=" * 60)

print("\n Business Criteria: ")
for c in evaluation['business_criteria']:
    status = 'PASS' if c['met'] else 'FAIL'
    print(f"  [{status}] {c['criterion']}")
    print(f"         Target: {c['target']}  |  Achieved: {c['achieved']}")

print("\n Technical Criteria: ")
for c in evaluation['technical_criteria']:
    status = 'PASS' if c['met'] else 'FAIL'
    print(f"  [{status}] {c['metric']}")
    print(f"         Target: {c['target']}  |  Achieved: {c['achieved']}")

print("\n Approved Models: ")
for m in evaluation['approved_models']:
    print(f"  - {m['model']}: {m['reason']}")

print("\n Rejected Models: ")
for m in evaluation['rejected_models']:
    print(f"  - {m['model']}: {m['reason']}")

print("\nOverall Conclusion:")
print(evaluation['overall_conclusion'])
# Out:
# ============================================================
# EVALUATION AGAINST BUSINESS SUCCESS CRITERIA
# ============================================================
#
#  Business Criteria:
#   [PASS] Predict California housing prices accurately enough to support analysis and decision-making
#          Target: R² >= 0.75 with low prediction error  |  Achieved: Random Forest (Tuned) achieved R² = 0.80 with RMSE = 0.46 and MAE = 0.30
#   [PASS] Support identification of undervalued areas by comparing predicted and actual values
#          Target: Model should generate reliable predictions that can be compared against actual values  |  Achieved: The best model produced predictions suitable for comparing expected and actual house values
#   [PASS] Identify important factors affecting house prices
#          Target: Selected model should allow interpretation of key drivers  |  Achieved: Tree-based models such as Random Forest and Gradient Boosting can be used to examine feature importance
#
#  Technical Criteria:
#   [PASS] R² Score
#          Target: >= 0.75  |  Achieved: 0.8031
#   [PASS] RMSE
#          Target: <= 0.50  |  Achieved: 0.508
#   [PASS] MAE
#          Target: <= 0.35  |  Achieved: 0.333
#
#  Approved Models:
#   - Random Forest (Tuned): Approved because it achieved the strongest overall performance and best satisfied the business and technical success criteria.
#   - Gradient Boosting: Approved because it produced strong regression performance and remained a valid alternative model.
#
#  Rejected Models:
#   - Linear Regression: Rejected because it showed weaker performance and was less able to capture the non-linear structure of housing price data.
#
# Overall Conclusion:
# The evaluation shows that the selected model meets the main business objectives and is suitable for the next stage of the project.

# %% [markdown]
# ---
# ### Task 2: Review Process
#
# Conduct a thorough review of the entire CRISP-DM process executed so far. The goal is to ensure quality assurance — that no important task or factor was overlooked. Consider:
#
# - **Completeness Check:** Were all relevant data sources considered? Were the data preparation steps sufficient?
# - **Methodology Review:** Were appropriate techniques used at each stage? Were there alternatives worth exploring?
# - **Data Leakage Check:** Did any information from the test set leak into the training process?
# - **Bias and Fairness:** Could the model introduce or amplify any biases? Is the model fair across different subgroups?
# - **Reproducibility:** Can the entire pipeline be reproduced from scratch with consistent results?
#
# **Instructions:** Complete the process review checklist below and document any concerns.

# %%
# TODO: Review the end-to-end process.

process_review = {
    "checklist": [
        {"item": "All relevant data sources were considered",      "status": "Yes", "notes": "The California Housing dataset was selected because it matched the project goal and contained useful economic and location features."},
        {"item": "Data preparation was thorough and documented",   "status": "Yes", "notes": "Missing values, duplicates, outliers, feature creation, scaling, and formatting were addressed in Phase 3."},
        {"item": "No data leakage between train and test sets",    "status": "Yes", "notes": "The dataset was split before evaluation, and the test set was used only for final performance assessment."},
        {"item": "Multiple modelling techniques were compared",    "status": "Yes", "notes": "Linear Regression, Random Forest, and Gradient Boosting were trained and compared in Phase 4."},
        {"item": "Model assumptions and limitations were considered", "status": "Partial", "notes": "The models were evaluated properly, but the dataset is still limited because it is district-level rather than individual-house level."},
        {"item": "Business objectives remain aligned with the solution", "status": "Yes", "notes": "The selected model supports price prediction, analysis of important variables, and undervaluation analysis."}
    ],
    "overall_quality": "Good",
    "areas_for_improvement": [
        "Try additional feature engineering based on geographic relationships.",
        "Test additional advanced models for comparison.",
        "Validate the solution on external or newer housing data if available."
    ]
}

# %%
# Display the process review
print("=== Process Review Checklist ===")
for item in process_review['checklist']:
    print(f"  [{item['status']:^8}] {item['item']}")
    if item['notes']:
        print(f"           Note: {item['notes']}")

print(f"\nOverall Quality: {process_review['overall_quality']}")
if process_review['areas_for_improvement']:
    print("Areas for Improvement:")
    for area in process_review['areas_for_improvement']:
        print(f"  - {area}")
# Out:
# === Process Review Checklist ===
#   [  Yes   ] All relevant data sources were considered
#            Note: The California Housing dataset was selected because it matched the project goal and contained useful economic and location features.
#   [  Yes   ] Data preparation was thorough and documented
#            Note: Missing values, duplicates, outliers, feature creation, scaling, and formatting were addressed in Phase 3.
#   [  Yes   ] No data leakage between train and test sets
#            Note: The dataset was split before evaluation, and the test set was used only for final performance assessment.
#   [  Yes   ] Multiple modelling techniques were compared
#            Note: Linear Regression, Random Forest, and Gradient Boosting were trained and compared in Phase 4.
#   [Partial ] Model assumptions and limitations were considered
#            Note: The models were evaluated properly, but the dataset is still limited because it is district-level rather than individual-house level.
#   [  Yes   ] Business objectives remain aligned with the solution
#            Note: The selected model supports price prediction, analysis of important variables, and undervaluation analysis.
#
# Overall Quality: Good
# Areas for Improvement:
#   - Try additional feature engineering based on geographic relationships.
#   - Test additional advanced models for comparison.
#   - Validate the solution on external or newer housing data if available.

# %% [markdown]
# ---
# ### Task 3: Determine Next Steps
#
# Based on the evaluation results and process review, decide on the next course of action. The three main options are:
#
# 1. **Proceed to Deployment:** The model meets all criteria and is ready for deployment.
# 2. **Iterate:** Go back to a previous phase (e.g., Data Preparation or Modelling) to improve the model before deployment.
# 3. **Terminate:** The project is not viable in its current form and should be re-scoped or abandoned.
#
# **Instructions:** Document your decision and provide a clear rationale.

# %%
# TODO: Determine and document the next steps.

next_steps = {
    "decision": "Proceed to Deployment",
    "rationale": "The tuned Random Forest model met the business and technical success criteria and is suitable for final reporting, and  deployment.",
    "if_iterating": {
        "return_to_phase": "",
        "specific_actions": []
    },
    "if_deploying": {
        "selected_model": "Random Forest (Tuned)",
        "deployment_notes": [
            "Use the selected model in the final report and presentation.",
            "Present predicted vs actual values and feature importance.",
            "Use predictions to support identification of potentially undervalued districts."
        ]
    }
}

# %%
# Display the decision
print("=" * 60)
print("NEXT STEPS DECISION")
print("=" * 60)
print(f"\nDecision  : {next_steps['decision']}")
print(f"Rationale : {next_steps['rationale']}")

if next_steps['decision'] == 'Iterate':
    print(f"\nReturn to: {next_steps['if_iterating']['return_to_phase']}")
    for action in next_steps['if_iterating']['specific_actions']:
        print(f"  - {action}")
elif next_steps['decision'] == 'Proceed to Deployment':
    print(f"\nModel to deploy: {next_steps['if_deploying']['selected_model']}")
    print("Deployment Notes:")
    for note in next_steps['if_deploying']['deployment_notes']:
        print(f"  - {note}")
# Out:
# ============================================================
# NEXT STEPS DECISION
# ============================================================
#
# Decision  : Proceed to Deployment
# Rationale : The tuned Random Forest model met the business and technical success criteria and is suitable for final reporting, and  deployment.
#
# Model to deploy: Random Forest (Tuned)
# Deployment Notes:
#   - Use the selected model in the final report and presentation.
#   - Present predicted vs actual values and feature importance.
#   - Use predictions to support identification of potentially undervalued districts.
