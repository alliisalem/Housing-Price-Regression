# %% [markdown]
# # Phase 6: Deployment
#
# **CRISP-DM Phase Description:**
# The final phase involves organising and presenting the project findings so that the customer can use them, or integrating the model into a live production system. Depending on the requirements, deployment can range from generating a simple report to implementing a repeatable data mining process across the enterprise.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ---
# ### Task 1: Plan Deployment
#
# Develop a strategy for putting the data mining results to practical use. This includes:
#
# - **Deployment Strategy:** How will the model be consumed? Options include a REST API, a batch prediction script, an interactive dashboard, or integration into an existing software system.
# - **Infrastructure Requirements:** What technical environment is needed (e.g., cloud services, web server, containerisation)?
# - **Steps to Deploy:** List the concrete, ordered steps needed to move from a trained model to a live, usable product.
# - **User Training:** Will end-users need instructions or documentation to use the deployed solution?
#
# **Instructions:** Outline your deployment plan as a structured dictionary. If building an API or script, sketch the basic structure in code.

# %%
# TODO: Plan the deployment of your model/solution.

deployment_plan = {
    "strategy": "Streamlit web application",
    "target_users": [
        "Real estate analysts",
        "Property investors",
    ],
    "deployment_environment": "Local machine or cloud deployment using Streamlit",
    "inputs": [
        "Prepared California housing features from Phase 3",
        "New area housing data with the same feature columns"
    ],
    "outputs": [
        "Predicted median house value",
        "Comparison of predicted vs actual values",
        "Identifies potential undervalued districts"
    ],
    "steps": [
        "Train and save the best-performing model from Phase 4",
        "Build a Streamlit app",
        "Load the saved model inside the Streamlit application",
        "Create input fields for housing features",
        "Generate housing price predictions from user input",
        "Display the prediction results, comparisons, and insights inside the web app"
    ],
    "success_condition": "The deployed Streamlit application should provide accurate and understandable housing price predictions."
}

# %%
# Optional: Sketch a basic deployment script or API structure

# Example: Saving the trained model for deployment
# import joblib
# MODEL_PATH = 'path/to/your/saved_model.pkl'
# joblib.dump(best_model, MODEL_PATH)
# print(f"Model saved to: {MODEL_PATH}")

# Example: Basic prediction function skeleton
# def predict(input_data: dict) -> dict:
#     """
#     Takes a dictionary of feature values,
#     returns the model's prediction.
#     """
#     model = joblib.load(MODEL_PATH)
#     input_df = pd.DataFrame([input_data])
#     prediction = model.predict(input_df)
#     return {"prediction": prediction.tolist()}

# %%
# Display the deployment plan
print(json.dumps(deployment_plan, indent=2))
# Out:
# {
#   "strategy": "Streamlit web application",
#   "target_users": [
#     "Real estate analysts",
#     "Property investors"
#   ],
#   "deployment_environment": "Local machine or cloud deployment using Streamlit",
#   "inputs": [
#     "Prepared California housing features from Phase 3",
#     "New area housing data with the same feature columns"
#   ],
#   "outputs": [
#     "Predicted median house value",
#     "Comparison of predicted vs actual values",
#     "Identifies potential undervalued districts"
#   ],
#   "steps": [
#     "Train and save the best-performing model from Phase 4",
#     "Build a Streamlit app",
#     "Load the saved model inside the Streamlit application",
#     "Create input fields for housing features",
#     "Generate housing price predictions from user input",
#     "Display the prediction results, comparisons, and insights inside the web app"
#   ],
#   "success_condition": "The deployed Streamlit application should provide accurate and understandable housing price predictions."
# }

# %% [markdown]
# ---
# ### Task 2: Plan Monitoring and Maintenance
#
# A deployed model is not "set and forget". Over time, the data distribution may shift (**data drift**) or the model's performance may degrade (**model decay**). This task creates a monitoring and maintenance plan:
#
# - **Performance Monitoring:** How and how often will the model's predictions be evaluated against actuals?
# - **Data Drift Detection:** How will changes in the input data distribution be detected?
# - **Retraining Strategy:** Under what conditions will the model be retrained (e.g., scheduled, triggered by performance drop)?
# - **Logging and Alerting:** What will be logged, and what triggers an alert?
#
# **Instructions:** Document your monitoring and maintenance plan.

# %%
# TODO: Plan monitoring and maintenance.

monitoring_plan = {
    "performance_monitoring": {
        "frequency": "Monthly",
        "metrics": ["R²", "RMSE", "MAE"],
        "goal": "Ensure the deployed Streamlit model continues to make accurate predictions over time."
    },
    "data_monitoring": {
        "frequency": "Monthly",
        "checks": [
            "Check for missing values in new input data",
            "Check for unusual outliers or feature drift",
            "Verify that new data follows the same structure as the training data"
        ]
    },
    "maintenance_actions": [
        "Retrain the model if performance drops significantly",
        "Update the dataset when newer housing data becomes available",
        "Review feature importance and model assumptions periodically"
    ],
    "risk_handling": "If model data changes, return to earlier CRISP-DM phases and improve data preparation or modelling."
}

# %%
# Display the monitoring plan
print(json.dumps(monitoring_plan, indent=2))
# Out:
# {
#   "performance_monitoring": {
#     "frequency": "Monthly",
#     "metrics": [
#       "R\u00b2",
#       "RMSE",
#       "MAE"
#     ],
#     "goal": "Ensure the deployed Streamlit model continues to make accurate predictions over time."
#   },
#   "data_monitoring": {
#     "frequency": "Monthly",
#     "checks": [
#       "Check for missing values in new input data",
#       "Check for unusual outliers or feature drift",
#       "Verify that new data follows the same structure as the training data"
#     ]
#   },
#   "maintenance_actions": [
#     "Retrain the model if performance drops significantly",
#     "Update the dataset when newer housing data becomes available",
#     "Review feature importance and model assumptions periodically"
#   ],
#   "risk_handling": "If model data changes, return to earlier CRISP-DM phases and improve data preparation or modelling."
# }

# %% [markdown]
# ---
# ### Task 3: Produce Final Report
#
# Compile a final summary of the entire project. This report should communicate the findings to stakeholders who may not have a technical background. It typically includes:
#
# - **Executive Summary:** A brief overview of the problem, approach, and key results.
# - **Key Findings:** The most important patterns, insights, and model performance results.
# - **Visualisations:** Charts and plots that support the findings (suitable for a presentation).
# - **Recommendations:** Actionable recommendations based on the analysis.
# - **Limitations:** Known limitations and caveats of the analysis.
#
# **Instructions:** Draft the final report content below. Include any code needed to generate summary visualisations.

# %%
# TODO: Draft the final report as a structured document.

final_report = {
    "title": "California Housing Price Prediction Using CRISP-DM",
    "executive_summary": "This project applied the CRISP-DM framework to build a regression model for predicting California housing prices. The goal was to support housing analysis, identify potentially undervalued districts, and understand the main factors affecting house values.",
    "business_problem": "The project addressed the challenge of estimating housing prices. Reliable predictions can support investment analysis and price comparison.",
    "data_summary": "The California Housing dataset was used. It includes features such as median income, house age, average rooms, average bedrooms, population, average occupancy, latitude, and longitude, with median house value as the target variable.",
    "methodology": [
        "Phase 1: Defined business objectives and project goals",
        "Phase 2: Explored the dataset and understood its structure",
        "Phase 3: Prepared the data by checking quality, handling duplicates and outliers",
        "Phase 4: Built and compared multiple regression models",
        "Phase 5: Evaluated the results against business and technical success criteria",
        "Phase 6: Planned Streamlit deployment, monitoring, and reporting"
    ],
    "modelling_results": {
        "best_model": "Random Forest (Tuned)",
        "reason_selected": "It achieved the strongest prediction performance and met the success criteria defined earlier in the project."
    },
    "key_findings": [
        "Tree-based regression models performed better than Linear Regression",
        "The selected model can support price estimation and undervaluation analysis",
        "Economic and geographic features are important drivers of housing prices",
        "The final model can be deployed using Streamlit for interactive predictions"
    ],
    "limitations": [
        "This dataset summarizes data by area rather than listing each home individually.",
        "Model performance depends on the available features and historical data",
        "Predictions may be less reliable for unusual or extreme observations"
    ],
    "recommendations": [
        "Use the best model in the final presentation and Streamlit app",
        "Monitor model performance over time",
        "Improve the solution in future work with better housing datasets"
    ]
}

# %%
# Display the final report
print("=" * 60)
print(f"FINAL REPORT: {final_report['title']}")
print("=" * 60)

print(f"\nExecutive Summary :\n{final_report['executive_summary']}")
print(f"\nBusiness Problem :\n{final_report['business_problem']}")
print(f"\nData Summary :\n{final_report['data_summary']}")

print("\nMethodology :")
for item in final_report['methodology']:
    print(f"- {item}")

print("\nModelling Results :")
for k, v in final_report['modelling_results'].items():
    print(f"- {k}: {v}")

print("\nKey Findings :")
for item in final_report['key_findings']:
    print(f"- {item}")

print("\nLimitations :")
for item in final_report['limitations']:
    print(f"- {item}")

print("\nRecommendations :")
for item in final_report['recommendations']:
    print(f"- {item}")
# Out:
# ============================================================
# FINAL REPORT: California Housing Price Prediction Using CRISP-DM
# ============================================================
#
# Executive Summary :
# This project applied the CRISP-DM framework to build a regression model for predicting California housing prices. The goal was to support housing analysis, identify potentially undervalued districts, and understand the main factors affecting house values.
#
# Business Problem :
# The project addressed the challenge of estimating housing prices. Reliable predictions can support investment analysis and price comparison.
#
# Data Summary :
# The California Housing dataset was used. It includes features such as median income, house age, average rooms, average bedrooms, population, average occupancy, latitude, and longitude, with median house value as the target variable.
#
# Methodology :
# - Phase 1: Defined business objectives and project goals
# - Phase 2: Explored the dataset and understood its structure
# - Phase 3: Prepared the data by checking quality, handling duplicates and outliers
# - Phase 4: Built and compared multiple regression models
# - Phase 5: Evaluated the results against business and technical success criteria
# - Phase 6: Planned Streamlit deployment, monitoring, and reporting
#
# Modelling Results :
# - best_model: Random Forest (Tuned)
# - reason_selected: It achieved the strongest prediction performance and met the success criteria defined earlier in the project.
#
# Key Findings :
# - Tree-based regression models performed better than Linear Regression
# - The selected model can support price estimation and undervaluation analysis
# - Economic and geographic features are important drivers of housing prices
# - The final model can be deployed using Streamlit for interactive predictions
#
# Limitations :
# - This dataset summarizes data by area rather than listing each home individually.
# - Model performance depends on the available features and historical data
# - Predictions may be less reliable for unusual or extreme observations
#
# Recommendations :
# - Use the best model in the final presentation and Streamlit app
# - Monitor model performance over time
# - Improve the solution in future work with better housing datasets

# %%
# Optional: Generate summary visualisations for the stakeholder presentation

# import matplotlib.pyplot as plt

# Example: Bar chart comparing model performance
# models = ['Model A', 'Model B', 'Model C']
# scores = [0.82, 0.88, 0.85]
#
# plt.figure(figsize=(8, 5))
# plt.bar(models, scores, color=['#4C72B0', '#55A868', '#C44E52'], edgecolor='black')
# plt.title('Model Performance Comparison', fontsize=14)
# plt.ylabel('F1-Score')
# plt.ylim(0, 1)
# for i, v in enumerate(scores):
#     plt.text(i, v + 0.02, f'{v:.2f}', ha='center', fontweight='bold')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ---
# ### Task 4: Review Project
#
# Conduct a project retrospective. Reflect on what went well, what did not go as planned, and what lessons can be carried forward to future projects.
#
# - **What went well?** Successes, effective techniques, good decisions.
# - **What could be improved?** Challenges, mistakes, or inefficiencies encountered.
# - **Lessons learned:** Key takeaways for future data science projects.
# - **Skills developed:** New skills or knowledge gained during the project.
#
# **Instructions:** Complete the project retrospective below.

# %%
# TODO: Conduct the project retrospective.

project_retrospective = {
    "went_well": [
        "The CRISP-DM framework provided a clear structure for the project.",
        "The California Housing dataset was suitable for regression and easy to work with.",
        "Comparing multiple models helped identify a final solution."
    ],
    "challenges": [
        "Some project phases required careful structure with the notebook template.",
        "The dataset was limited rather than detailed kind of data.",
        "Model performance could still be improved with a better data and additional tuning."
    ],
    "lessons_learned": [
        "It is important to match evaluation metrics to the problem type.",
        "Data preparation has a major effect on final model performance.",
        "Model tuning can improve performance compared to default settings."
    ],
    "skills_developed": [
        "Use more detailed housing datasets in future work.",
        "Explore more advanced regression methods.",
        "Build a more interactive deployment interface for end users."
    ]
}

# %%
# Display the retrospective
print("=" * 60)
print("PROJECT RETROSPECTIVE")
print("=" * 60)

sections = [
    ("What Went Well", project_retrospective["went_well"]),
    ("Challenges", project_retrospective["challenges"]),
    ("Lessons Learned", project_retrospective["lessons_learned"]),
    ("Future Actions", project_retrospective["skills_developed"])
]

for title, items in sections:
    print(f"\n {title} :")
    for item in items:
        print(f"- {item}")
# Out:
# ============================================================
# PROJECT RETROSPECTIVE
# ============================================================
#
#  What Went Well :
# - The CRISP-DM framework provided a clear structure for the project.
# - The California Housing dataset was suitable for regression and easy to work with.
# - Comparing multiple models helped identify a final solution.
#
#  Challenges :
# - Some project phases required careful structure with the notebook template.
# - The dataset was limited rather than detailed kind of data.
# - Model performance could still be improved with a better data and additional tuning.
#
#  Lessons Learned :
# - It is important to match evaluation metrics to the problem type.
# - Data preparation has a major effect on final model performance.
# - Model tuning can improve performance compared to default settings.
#
#  Future Actions :
# - Use more detailed housing datasets in future work.
# - Explore more advanced regression methods.
# - Build a more interactive deployment interface for end users.

# %% [markdown]
# ---
#
# ## Key Takeaway on Iteration
#
# While the six CRISP-DM phases are presented **sequentially** in these notebooks, in practice the process is **highly iterative**. Real-world data science projects rarely follow a straight line from Phase 1 to Phase 6.
#
# Common iteration patterns include:
#
# - **Modelling → Data Preparation:** If the model performs poorly, you may return to Phase 3 to engineer new features, clean data differently, or acquire more data.
# - **Evaluation → Modelling:** If the model does not meet the business success criteria, you may go back to Phase 4 to try different algorithms or tune hyperparameters.
# - **Deployment → Evaluation:** If the deployed model underperforms in production (data drift), you may return to Phase 5 to re-evaluate and then to Phase 3/4 to retrain.
# - **Any Phase → Business Understanding:** New findings in later phases may redefine the business objectives or success criteria originally set in Phase 1.
#
# ```
# ┌───────────────────────────────────────────────────────────┐
# │                     CRISP-DM Lifecycle                    │
# │                                                           │
# │   Phase 1 ──► Phase 2 ──► Phase 3 ──► Phase 4            │
# │   Business    Data        Data        Modelling           │
# │   Under.      Under.      Prep.           │               │
# │     ▲                       ▲              │               │
# │     │                       │              ▼               │
# │     │                       └──────── Phase 5             │
# │     │                                Evaluation           │
# │     │                                    │                │
# │     │                                    ▼                │
# │     └──────────────────────────────  Phase 6              │
# │                                     Deployment            │
# └───────────────────────────────────────────────────────────┘
# ```
#
# > **Remember:** Iteration is not failure — it is the *expected* workflow. Each cycle through the process deepens your understanding of both the data and the business problem, ultimately leading to a better solution.
